# %% [markdown]
# # Analisis.

# %%
import os
import requests
import json
from dotenv import load_dotenv
import pymongo

import geopandas as gpd
from cartoframes.auth import set_default_credentials
from cartoframes.viz import Map, Layer, popup_element, default_legend, animation_style, basic_style,basic_legend, color_category_style, color_category_legend, cluster_size_style
set_default_credentials('cartovl')
set_default_credentials('cartoframes')

import plotly.express as px
import plotly.graph_objects as go
from getpass import getpass
import pandas as pd
import time
import importlib
import data.graphs as gr
importlib.reload(gr)

import data.graphs as gr
importlib.reload(gr)
# Out:
# <module 'data.graphs' from 'd:\\ironhack\\proyectos\\GeoSpatialData_proy3\\data\\graphs.py'>

# %% [markdown]
# ## 1. Searching for city.

# %% [markdown]
# exporting csv file of clean cities.

# %%
cities = pd.read_csv("..\GeoSpatialData_proy3\csv\location_clean.csv")

# %%
cities.head(3)
# Out:
#           cities country  count
# 2  San Francisco     USA      9
# 1       New York     USA      6
# 5         London     GBR      4

# %%
clean = gr.clean_cities_df (cities)

# %%
fig = px.bar(clean, x="cities", y="count", color=["#edbb8a", "#edbb8a", "#edbb8a", "#edbb8a", "#edbb8a", "#edbb8a", "#edbb8a", "#edbb8a","#edbb8a", "#edbb8a"],title='music business in cities')
fig.show()

# %% [markdown]
# do some tables to analize witch city is the company going to.

# %% [markdown]
# ## 2. Music business.

# %%
music = pd.read_csv("..\GeoSpatialData_proy3\csv\musiccompanies_newyork.csv")
music.sample()
# Out:
#    Unnamed: 0     name   latitud  longitude
# 1           1  Animoto  40.72948 -74.000195

# %%
music_points = gr.carto_points (music)

# %%
gr.carto_music (music_points)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ## 3. Startups.

# %%
startups_ex = pd.read_csv("..\GeoSpatialData_proy3\csv\startups_newyork.csv")

# %%
startups = gr.carto_points (startups_ex)

# %% [markdown]
# startups and already big companies with more than a million of founding.

# %%
gr.carto_startups (startups)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ## 4. Foursquare.

# %%
token = getpass()

# %% [markdown]
# ### 4.1. Starbucks.

# %%
starbucks = pd.read_csv("..\GeoSpatialData_proy3\csv\starbucks_newyork.csv")
starbucks.sample()
# Out:
#     Unnamed: 0       name   latitude  longitude
# 38          38  Starbucks  40.748376 -73.985099

# %%
starbucks = gr.starbucks_carto_points (starbucks)

# %%
gr.carto_starbucks (starbucks)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### 4.2. Schools.

# %% [markdown]
# Looked for schools within the goberment in the list we have highschools, music schools, etc.

# %%
schools_ex = pd.read_csv("..\GeoSpatialData_proy3\csv\schools_newyork.csv")

# %%
schools = gr.starbucks_carto_points (schools_ex)

# %%
gr.carto_schools (schools)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### 4.3. Bars.

# %% [markdown]
# Filter to look for bars within music environment, like piano bars or somme that have small presentations.

# %%
bars_ex = pd.read_csv("..\GeoSpatialData_proy3\csv\\bars_newyork.csv")

# %%
bars_df = gr.starbucks_carto_points (bars_ex)

# %%
gr.carto_bars (bars_df)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### 4.4. Concerts.

# %% [markdown]
# Music environment around the city, it throws places like parks, theaters, museums and arts.

# %%
concerts = pd.read_csv("..\GeoSpatialData_proy3\csv\\concerts_newyork.csv")

# %%
concert_df = gr.starbucks_carto_points (concerts)

# %%
gr.carto_concerts (concert_df)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ## 5. Neighbourhoods

# %% [markdown]
# I put an importance porcentage to each space that I looked around, and for each I did a geo intersection to get the neightbourhoods where theres more impact of each porcentage of each point, so at the end I exported a df with the sum of porcentage for each neigh.

# %%
neigh = pd.read_csv("..\GeoSpatialData_proy3\csv\\neigh_newyork.csv")

# %%
neigh = pd.DataFrame(neigh)

# %%
neigh["sum"] = neigh.fillna(0)["concerts %"] + neigh.fillna(0)["bars %"] + neigh.fillna(0)["schools %"] + neigh.fillna(0)["starbucks %"] + neigh.fillna(0)["startups. %"] + neigh.fillna(0)["music_comp. %"]

# %%
fig = px.pie(neigh[:10], values='sum', names='neighbourhood', color_discrete_sequence=px.colors.sequential.RdBu, title='Value of neighbourhoods')
fig.show()

# %% [markdown]
# ## 6. Matching neighbourhoods with the points of interest.

# %%
gr.carto_layers (music_points, startups, starbucks, schools, bars_df, concert_df)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
#https://github.com/CartoDB/cartoframes/blob/develop/docs/examples/data_visualization/legends/color_bins_legend.ipynb
#https://jiffyclub.github.io/palettable/cartocolors/diverging/#geyser_7
#https://carto.com/carto-colors/
# colores : #009B9E,#42B7B9,#A7D3D4,#F1F1F1,#E4C1D9,#D691C1,#C75DAB
# colores : #008080,#70a494,#b4c8a8,#f6edbd,#edbb8a,#de8a5a,#ca562c

# %% [markdown]
# wanted to find subway stations, airport, geojson polygon in map.

# %% [markdown]
# # Analisis.

# %%
import os
import requests
import json
from dotenv import load_dotenv
import pymongo

import geopandas as gpd
from cartoframes.auth import set_default_credentials
from cartoframes.viz import Map, Layer, popup_element, default_legend, animation_style, basic_style,basic_legend, color_category_style, color_category_legend
set_default_credentials('cartovl')
set_default_credentials('cartoframes')

import plotly.express as px
import plotly.graph_objects as go
from getpass import getpass
import pandas as pd
import time
import importlib
import data.graphs as gr
importlib.reload(gr)

import data.graphs as gr
importlib.reload(gr)
# Out:
# <module 'data.graphs' from 'd:\\ironhack\\proyectos\\GeoSpatialData_proy3\\data\\graphs.py'>

# %% [markdown]
# ## 1. Searching for city.

# %% [markdown]
# exporting csv file of clean cities.

# %%
cities = pd.read_csv("..\GeoSpatialData_proy3\csv\location_clean.csv")

# %%
cities.head(3)
# Out:
#    Unnamed: 0         cities country  count
# 0           0      San Diego     USA      2
# 1           1       New York     USA      6
# 2           2  San Francisco     USA      9

# %%
clean = gr.clean_cities_df (cities)

# %%
fig = px.bar(clean, x="cities", y="count")
fig.show()

# %% [markdown]
# do some tables to analize witch city is the company going to.

# %% [markdown]
# ### 2. Music business.

# %%
music = pd.read_csv("..\GeoSpatialData_proy3\csv\musiccompanies_newyork.csv")
music.sample()
# Out:
#    Unnamed: 0     name   latitud  longitude
# 1           1  Animoto  40.72948 -74.000195

# %%
music_points = gr.carto_points (music)

# %%
gr.carto_music (music_points)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ## 2. Startups.

# %%
startups = pd.read_csv("..\GeoSpatialData_proy3\csv\startups_newyork.csv")
startups.sample()
# Out:
#     Unnamed: 0            name category_code  latitud  longitude
# 35          35  WebMediaBrands           web      NaN        NaN

# %%
startups = gr.carto_points (startups)

# %% [markdown]
# startups and already big companies with more than a million of founding.

# %%
gr.carto_startups (startups)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ## Foursquare.

# %%
token = getpass()

# %% [markdown]
# ### 3. Starbucks.

# %%
starbucks = pd.read_csv("..\GeoSpatialData_proy3\csv\starbucks_newyork.csv")
starbucks.sample()
# Out:
#    Unnamed: 0         name   latitude  longitude
# 6           6  Lotus Hotel  40.746511 -73.986249

# %%
starbucks = gr.starbucks_carto_points (starbucks)

# %%
gr.carto_starbucks (starbucks)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### Schools.

# %%
schools = pd.read_csv("..\GeoSpatialData_proy3\csv\schools_newyork.csv")
schools
# Out:
#     Unnamed: 0                                               name   latitude  \
# 0            0                                      Yessian Music  40.739650
# 1            1                                 Primary Wave Music  40.735283
# 2            2               Third Street Music School Settlement  40.730899
# 3            3                                     MatchaBar Soho  40.723671
# 4            4                                 The Music Building  40.754957
# 5            5                                   Storefront Music  40.750025
# 6            6                              Gymboree Play & Music  40.747792
# 7            7                                 Alex Morelli Music  40.737289
# 8            8                       Williamsburg School of Music  40.710759
# 9            9                          Brooklyn Academy of Music  40.686607
# 10          10                                    In Ya Ear Music  40.754032
# ...

# %%
schools = gr.starbucks_carto_points (schools)

# %%
gr.carto_schools (schools)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### 3.4. Bars.

# %%
bars = pd.read_csv("..\GeoSpatialData_proy3\csv\\bars_newyork.csv")
bars
# Out:
#     Unnamed: 0                                               name   latitude  \
# 0            0                                        Juice Press  40.739165
# 1            1                        Sogno Toscano Market & Wine  40.735834
# 2            2                                  Kobrick Coffee Co  40.740323
# 3            3                           Soho House 6th Floor Bar  40.740486
# 4            4                                            Entwine  40.737383
# 5            5                                      Turks & Frogs  40.735851
# 6            6                                         Rosemary's  40.734813
# 7            7                                  The Marlton Hotel  40.732524
# 8            8                    Juice Generation - Union Square  40.737506
# 9            9                                          Irvington  40.736519
# 10          10                                     The Clocktower  40.741244
# ...

# %%
bars = gr.starbucks_carto_points (bars)

# %%
gr.carto_bars (bars)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### 3.5. Concerts.

# %%
concerts = pd.read_csv("..\GeoSpatialData_proy3\csv\\concerts_newyork.csv")
concerts
# Out:
#     Unnamed: 0                                 name   latitude  longitude
# 0            0                      Partners Coffee  40.734909 -74.002256
# 1            1          The Beach at Dream Downtown  40.742155 -74.003634
# 2            2              The Standard, High Line  40.740796 -74.007925
# 3            3                    Hudson River Park  40.735390 -74.010353
# 4            4                             The Dish  40.743603 -73.999979
# 5            5                The Progressive House  40.741908 -73.994847
# 6            6               Washington Square Park  40.730939 -73.997471
# 7            7                    Union Square Park  40.735267 -73.991048
# 8            8                      The Corner Cafe  40.743478 -73.992637
# 9            9      Juice Generation - Union Square  40.737506 -73.990045
# 10          10                        Pret A Manger  40.730106 -73.992374
# 11          11                  Madison Square Park  40.742360 -73.988095
# ...

# %%
concert = gr.starbucks_carto_points (concerts)

# %%
gr.carto_concerts (concert)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
from palettable.cartocolors.diverging import Geyser_7
Map([Layer(music_points, basic_style(size=13, opacity=10, color="#008080"),legends=default_legend('music')),
    Layer(starbucks, basic_style(size=13, opacity=10, color="#70a494"), legends=default_legend("starbucks")),
    Layer(startups, basic_style(size=13, opacity=10, color="#b4c8a8"), legends=default_legend("Startups")),
    Layer(schools, basic_style(size=13, opacity=10, color="#f6edbd"), legends=default_legend("schools")),
    Layer(bars, basic_style(size=13, opacity=10, color="#edbb8a"), legends=default_legend("bars")),
    Layer(concert, basic_style(size=13, opacity=10, color="#de8a5a"), legends=default_legend("concerts"))], layer_selector=True)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
#https://github.com/CartoDB/cartoframes/blob/develop/docs/examples/data_visualization/legends/color_bins_legend.ipynb
#https://jiffyclub.github.io/palettable/cartocolors/diverging/#geyser_7
#https://carto.com/carto-colors/
# colores : #009B9E,#42B7B9,#A7D3D4,#F1F1F1,#E4C1D9,#D691C1,#C75DAB
# colores : #008080,#70a494,#b4c8a8,#f6edbd,#edbb8a,#de8a5a,#ca562c
